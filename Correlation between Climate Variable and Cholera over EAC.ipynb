# %%
import pandas as pd

# %%
d_data=pd.read_csv("/Users/C4/New_data.csv",index_col ="Country")

# %%
d_data
# Out:
#          Country ID  Year  NumberOfReportedCasesOfCholera        CPRE  \
# Country
# Burundi           1  1978                          8297.0  108.300000
# Burundi           1  1979                           915.0  110.900000
# Burundi           1  1980                          2039.0   93.100000
# Burundi           1  1981                           582.0  104.800000
# Burundi           1  1982                           415.0  102.000000
# ...             ...   ...                             ...         ...
# DRC               6  2012                         33661.0  133.650000
# DRC               6  2013                         26944.0  140.833333
# DRC               6  2014                         22203.0  140.833333
# DRC               6  2015                         19182.0  140.833333
# DRC               6  2016                         28093.0  140.833333
#
#               CTMP       CTMN       CTMX       CWET       CVAP       CDTR  \
# Country
# ...

# %%
Burundi = d_data.loc["Burundi"]
DRC = d_data.loc["DRC"]
Rwanda = d_data.loc["Rwanda"]
Uganda =d_data.loc["Uganda"]
Kenya=d_data.loc["Kenya"]
Tanzania=d_data.loc[" Tanzania"]

# %%
# Import library


import matplotlib.pyplot as plt

plt.figure(figsize=(20,20))

# Create figure and multiple plots
fig, axes = plt.subplots(nrows=3, ncols=2)

# Auto adjust
plt.subplot(3, 2, 1)

plt.scatter(Burundi.PCA1 ,Burundi.NumberOfReportedCasesOfCholera,label='blogs_read', 
         linewidth=3)
plt.title("Burundi")




plt.subplot(3, 2, 2)

plt.scatter(Tanzania.PCA1 ,Tanzania.NumberOfReportedCasesOfCholera,label='blogs_read', 
         linewidth=3)
plt.title("Tanzania")



plt.subplot(3, 2, 3)

plt.scatter(Kenya.PCA1 ,Kenya.NumberOfReportedCasesOfCholera,label='blogs_read', 
         linewidth=3)
plt.title("Kenya")



plt.subplot(3, 2, 4)
plt.scatter(Uganda.PCA1 ,Uganda.NumberOfReportedCasesOfCholera,label='blogs_read', 
         linewidth=3)
plt.title("Uganda")

plt.subplot(3, 2, 5)
plt.scatter(Rwanda.PCA1 ,Rwanda.NumberOfReportedCasesOfCholera,label='blogs_read', 
         linewidth=3)
plt.title("Rwanda")


plt.subplot(3, 2, 6)
plt.scatter(DRC.PCA1 ,DRC.NumberOfReportedCasesOfCholera,label='blogs_read', 
         linewidth=3)
plt.title("DRC")


plt.tight_layout()
plt.show()
# Display

# %%
# Import library


import matplotlib.pyplot as plt

plt.figure(figsize=(20,20))

# Create figure and multiple plots
fig, axes = plt.subplots(nrows=3, ncols=2)

# Auto adjust
plt.subplot(3, 2, 1)

plt.scatter(Burundi.PCA2 ,Burundi.NumberOfReportedCasesOfCholera,label='blogs_read', 
         linewidth=3)
plt.title("Burundi")




plt.subplot(3, 2, 2)

plt.scatter(Tanzania.PCA2 ,Tanzania.NumberOfReportedCasesOfCholera,label='blogs_read', 
         linewidth=3)
plt.title("Tanzania")



plt.subplot(3, 2, 3)

plt.scatter(Kenya.PCA2 ,Kenya.NumberOfReportedCasesOfCholera,label='blogs_read', 
         linewidth=3)
plt.title("Kenya")



plt.subplot(3, 2, 4)
plt.scatter(Uganda.PCA2 ,Uganda.NumberOfReportedCasesOfCholera,label='blogs_read', 
         linewidth=3)
plt.title("Uganda")

plt.subplot(3, 2, 5)
plt.scatter(Rwanda.PCA2 ,Rwanda.NumberOfReportedCasesOfCholera,label='blogs_read', 
         linewidth=3)
plt.title("Rwanda")


plt.subplot(3, 2, 6)
plt.scatter(DRC.PCA2 ,DRC.NumberOfReportedCasesOfCholera,label='blogs_read', 
         linewidth=3)
plt.title("DRC")


plt.tight_layout()
plt.show()
# Display
